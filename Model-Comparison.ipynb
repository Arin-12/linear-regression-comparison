# %% [markdown]
# <a href="https://colab.research.google.com/github/Arin-12/linear-regression-comparison/blob/main/MyLR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class My_LR:
  def __init__(self):
    self.m = None
    self.b = None

  def fit(self,X_train,y_train):
    X_mean=X_train.mean()
    y_mean=y_train.mean()
    for i in range(X_train.shape[0]):
      num=(X_train[i]-X_mean)*(y_train[i]-y_mean)
      den=(X_train[i]-X_mean)*(X_train[i]-X_mean)
      self.m=num.sum()/den.sum()
      self.b=y_mean-(self.m*X_mean)
    print(self.m)
    print(self.b)
  def predict(self,X_test):
    return self.m*X_test+self.b

# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score as r2,mean_squared_error as mse
import matplotlib.pyplot as plt

# %%
X,y=make_regression(n_samples=500,n_features=1,noise=20 , random_state=42)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
lr=My_LR()
lr.fit(X_train,y_train)
# Out:
# 54.59847899002643
# -1.0990217063146446

# %%
y_pred=lr.predict(X_test)

# %%
mse(y_test,y_pred)
# Out:
# 470.4644830953106

# %%
r2(y_test,y_pred)
# Out:
# 0.8870789257419551

# %%
plt.scatter(X_test,y_test)
plt.plot(X_test,y_pred,color='red')
plt.show()

# %%
X1,y1=make_regression(n_samples=500,n_features=1,noise=20 , random_state=42)

# %%
X_train1,X_test1,y_train1,y_test1=train_test_split(X1,y1,test_size=0.2,random_state=2)

# %%
model=LinearRegression()
model.fit(X_train1,y_train1)
# Out:
# LinearRegression()

# %%
y_pred1=model.predict(X_test1)

# %%
model.intercept_
# Out:
# np.float64(-1.0935099430490975)

# %%
model.coef_
# Out:
# array([63.24083765])

# %%
print("MSE=",mse(y_test1,y_pred1))
print("R2=",r2(y_test1,y_pred1 ))
# Out:
# MSE= 383.1220180797921
# R2= 0.9080428992878603

# %%
plt.scatter(X_test1,y_test1)
plt.plot(X_test1,y_pred1,color='red')
plt.show()

# %%
X2,y2=make_regression(n_samples=500,n_features=1,noise=20 , random_state=42)
X2_train , X2_test , y2_train , y2_test = train_test_split(X2,y2,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import SGDRegressor
sgd=SGDRegressor(max_iter=100,learning_rate='adaptive',eta0=0.01)
sgd.fit(X2_train,y2_train)
# Out:
# SGDRegressor(learning_rate='adaptive', max_iter=100)

# %%
y_pred3=sgd.predict(X2_test)

# %%
print(sgd.intercept_)
print(sgd.coef_)
# Out:
# [-1.08235307]
# [63.24333731]

# %%
print("MSE=",mse(y2_test,y_pred3))
print("R2=",r2(y2_test,y_pred3 ))
# Out:
# MSE= 383.0819034117518
# R2= 0.9080525276266008

# %%
plt.scatter(X2_test,y2_test)
plt.plot(X2_test,y_pred3,color='red')
plt.show()

# %%
X3,y3=make_regression(n_samples=500,n_features=1,noise=20 , random_state=42)
X3_train,X3_test,y3_train,y3_test=train_test_split(X3,y3,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import Ridge
ridge=Ridge(alpha=0.1)
ridge.fit(X3_train,y3_train)
# Out:
# Ridge(alpha=0.1)

# %%
y_pred4=ridge.predict(X3_test)

# %%
print(ridge.intercept_)
print(ridge.coef_)
# Out:
# -1.0935203088706023
# [63.22458421]

# %%
print("MSE=",mse(y3_test,y_pred4))
print("R2=",r2(y3_test,y_pred4 ))
# Out:
# MSE= 383.1579909890674
# R2= 0.9080342650557227
